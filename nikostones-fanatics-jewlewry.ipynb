# %%
import pandas as pd

# %%
df = pd.read_csv("data/Fanatics-Product-Catalog_IR.txt", sep="\t")
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_10600\1164394929.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Fanatics-Product-Catalog_IR.txt", sep="\t")

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    Unique Merchant SKU                                       Product Name  \
# 0              2866017  Women's Florida Panthers Sterling Silver Small...
# 1              5257010  Men's Under Armour Gray Virginia Tech Hokies S...
# 2            200180351  Women's Antigua  Navy Jacksonville Jumbo Shrim...
# 3            200465364   Keyscaper  Rey Mysterio Galaxy Impact Clear Case
# 4            201060326  Women's Cutter & Buck  Gray Los Angeles Dodger...
#
#                                          Product URL  \
# 0  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 3  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 4  https://fanatics.93n6tx.net/c/5567077/669352/9...
#
#                                            Image URL  Current Price  \
# 0  https://feeds.frgimages.com/_pi2866000_ff_2866...          74.99
# 1  https://feeds.frgimages.com/_pi5257000_ff_5257...          39.99
# 2  https://feeds.frgimages.com/_ss5_p-200180351+u...          74.99
# 3  https://feeds.frgimages.com/_ss5_p-200465364+u...          34.99
# 4  https://feeds.frgimages.com/_ss5_p-201060326+u...         234.99
#
#   Stock Availability Condition  EAN  \
# 0                  Y       New  NaN
# 1                  Y       New  NaN
# 2                  Y       New  NaN
# 3                  Y       New  NaN
# 4                  Y       New  NaN
#
#                                                  UPC ISBN  ...  Numeric1  \
# 0                                       191101152788  NaN  ...       NaN
# 1  197141891403;197141891397;197141891441;1971418...  NaN  ...       NaN
# 2  197719364124;197719364094;197719364117;1977193...  NaN  ...       NaN
# 3  197281950916;197281172295;197281172028;1972811...  NaN  ...       NaN
# 4  197948909646;197948909639;197948909660;1979489...  NaN  ...       NaN
#
#    Numeric2  Numeric3  Money1  Money2 Money3 Currency  Shipping Region Labels  \
# 0      0.39       NaN     NaN     NaN    NaN      USD              NaN    NaN
# 1      0.41       NaN     NaN     NaN    NaN      USD              NaN    NaN
# 2      0.41       NaN     NaN     NaN    NaN      USD              NaN    NaN
# 3      0.50       NaN     NaN     NaN    NaN      USD              NaN    NaN
# 4      0.40       NaN     NaN     NaN    NaN      USD              NaN    NaN
#
#    Promotion
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (960076, 70)

# %%
filtered_df = df[df['Product Name'].str.contains("Jewelry")]

# %%
filtered_df['Text1'].value_counts()
# Out:
# Text1
# Sports & Outdoors~Fan Shop~Sports Souvenirs~Pins    6
# Name: count, dtype: int64

# %%
filtered_df['Text2'].value_counts()
# Out:
# Text2
# Jewelry~Beads & Jewelry          46
# Beads & Jewelry~Jewelry          43
# Pins & Patches~Patches & Pins     4
# Patches & Pins~Pins & Patches     2
# Name: count, dtype: int64

# %%
filtered_df['Text3'].value_counts()
# Out:
# Text3
# Chicago Bears              2
# Los Angeles Chargers       2
# Los Angeles Rams           2
# Green Bay Packers          2
# New England Patriots       2
#                           ..
# Michigan State Spartans    1
# Kansas State Wildcats      1
# Kansas Jayhawks            1
# Texas Tech Red Raiders     1
# Oregon State Beavers       1
# Name: count, Length: 89, dtype: int64

# %%
filtered_df2 = df[df['Text2'].str.contains("Jewelry", na=False)]

# %%
filtered_df2['Text2'].value_counts().head(10)
# Out:
# Text2
# Beads & Jewelry~Jewelry~Watches    3304
# Watches~Jewelry~Beads & Jewelry    3270
# Jewelry~Watches~Beads & Jewelry    3247
# Jewelry~Beads & Jewelry~Watches    3235
# Watches~Beads & Jewelry~Jewelry    3224
# Beads & Jewelry~Watches~Jewelry    3201
# Beads & Jewelry~Jewelry            2718
# Jewelry~Beads & Jewelry            2594
# Ties~Jewelry~Beads & Jewelry        272
# Beads & Jewelry~Jewelry~Ties        263
# Name: count, dtype: int64

# %%
filtered_df2['Text1'].value_counts().head(10)
# Out:
# Text1
# Sports & Outdoors~Fan Shop~Watches                                   19481
# Sports & Outdoors~Fan Shop~Jewelry~Earrings                           1882
# Sports & Outdoors~Fan Shop~Jewelry~Necklaces & Pendants~Pendants      1778
# CuffLinks|HardLines|Jewelry                                           1613
# Sports & Outdoors~Fan Shop~Jewelry~Bracelets                          1186
# Sports & Outdoors~Fan Shop~Jewelry~Necklaces & Pendants~Necklaces     1171
# Sports & Outdoors~Fan Shop~Jewelry~Charms                              649
# Sports & Outdoors~Fan Shop~Jewelry~Rings                               260
# Bands|HardLines|Jewelry                                                 37
# Sports & Outdoors~Fan Shop~Jewelry                                      30
# Name: count, dtype: int64

# %% [markdown]
# ### Creación DF solo con Jewelry

# %%
# create a new df whehre Text1 does not contain "Watches"

#new_df = df[~df['Text1'].str.contains("Watches", na=False)]
# new_df = df[~df['Text2'].str.contains("Watches", na=False)]
new_df = df[df['Text1'].str.contains("Jewelry", na=False)]

# %%
#new_df['Text1'].value_counts().head(10)

new_df.shape
# Out:
# (8606, 70)

# %%
new_df.head(20)
# Out:
#       Unique Merchant SKU                                       Product Name  \
# 0                 2866017  Women's Florida Panthers Sterling Silver Small...
# 54                4647126                  Silver Georgetown Hoyas Cufflinks
# 88                5180826             Gold San Francisco Dons Logo Cufflinks
# 183             201094121      BaubleBar Mickey & Minnie Heart Drop Earrings
# 620               4896760             Silver Nichols College Bison Cufflinks
# 692             200532585  Women's Texas Tech Red Raiders Enamel Hinge Ba...
# 794               4801665  Men's Silver Simmons University Sharks Tie Tac...
# 846             200070263  Brianna Cannon Tennessee Volunteers Large Word...
# 1387              2854885  Women's Oklahoma Sooners Sterling Silver XS Da...
# 1467              3627822  Women's Alabama Crimson Tide Sterling Silver L...
# 1488              4778491                      Gold Liberty Flames Cufflinks
# 1506            201200285                     Gold Wyoming Cowboys Lapel Pin
# 1524              3384697             Men's Silver Toronto Raptors Cufflinks
# 1604              5177433     Gold Kansas State Wildcats Team Logo Lapel Pin
# 1652            201495577  Women's Nebraska Huskers Enamel Logo Hinge Bangle
# 2032            201201176               Gold Savannah State Tigers Cufflinks
# 2239              2201078  Women's WinCraft Silver New York Yankees Round...
# 2265              3640854  Women's Chicago White Sox Logo Bracelet with E...
# 2391              3382464  Women's Luca + Danni Silver Cleveland Indians ...
# 2542              4974222  New York Mets Sugar Skull Cufflinks & Lapel Pi...
#
#                                             Product URL  \
# 0     https://fanatics.93n6tx.net/c/5567077/669352/9...
# 54    https://fanatics.93n6tx.net/c/5567077/669352/9...
# 88    https://fanatics.93n6tx.net/c/5567077/669352/9...
# 183   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 620   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 692   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 794   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 846   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1387  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1467  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1488  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1506  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1524  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1604  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1652  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2032  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2239  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2265  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2391  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2542  https://fanatics.93n6tx.net/c/5567077/669352/9...
#
#                                               Image URL  Current Price  \
# 0     https://feeds.frgimages.com/_pi2866000_ff_2866...          74.99
# 54    https://feeds.frgimages.com/_pi4647000_ff_4647...          79.99
# 88    https://feeds.frgimages.com/_pi5180000_ff_5180...          79.99
# 183   https://feeds.frgimages.com/_ss5_p-201094121+u...          57.99
# 620   https://feeds.frgimages.com/_pi4896000_ff_4896...          79.99
# 692   https://feeds.frgimages.com/_ss5_p-200532585+u...          46.00
# 794   https://feeds.frgimages.com/_pi4801000_ff_4801...          49.99
# 846   https://feeds.frgimages.com/_ss5_p-200070263+u...          74.99
# 1387  https://feeds.frgimages.com/_pi2854000_ff_2854...          59.99
# 1467  https://feeds.frgimages.com/_pi3627000_ff_3627...          54.99
# 1488  https://feeds.frgimages.com/_pi4778000_ff_4778...          79.99
# 1506  https://feeds.frgimages.com/_ss5_p-201200285+u...          44.99
# 1524  https://feeds.frgimages.com/_pi3384000_ff_3384...          99.99
# 1604  https://feeds.frgimages.com/_pi5177000_ff_5177...          44.99
# 1652  https://feeds.frgimages.com/_ss5_p-201495577+u...          45.99
# 2032  https://feeds.frgimages.com/_ss5_p-201201176+u...          79.99
# 2239  https://feeds.frgimages.com/_pi2201000_ff_2201...          11.99
# 2265  https://feeds.frgimages.com/_pi3640000_ff_3640...         119.99
# 2391  https://feeds.frgimages.com/_pi3382000_ff_3382...          54.99
# 2542  https://feeds.frgimages.com/_pi4974000_ff_4974...         119.99
#
#      Stock Availability Condition  EAN           UPC ISBN  ...  Numeric1  \
# 0                     Y       New  NaN  191101152788  NaN  ...       NaN
# 54                    Y       New  NaN  194932404149  NaN  ...       NaN
# 88                    Y       New  NaN  194932872634  NaN  ...       NaN
# 183                   Y       New  NaN  889967870280  NaN  ...       NaN
# 620                   Y       New  NaN  194932625148  NaN  ...       NaN
# 692                   Y       New  NaN  810140725332  NaN  ...       NaN
# 794                   Y       New  NaN  194932545767  NaN  ...       NaN
# 846                   Y       New  NaN  810134531093  NaN  ...       NaN
# 1387                  Y       New  NaN  886774957579  NaN  ...       NaN
# 1467                  Y       New  NaN  886774702759  NaN  ...       NaN
# 1488                  Y       New  NaN  194932499589  NaN  ...       NaN
# 1506                  Y       New  NaN  195943432640  NaN  ...       NaN
# 1524                  Y       New  NaN  848873049722  NaN  ...       NaN
# 1604                  Y       New  NaN  194932868682  NaN  ...       NaN
# 1652                  Y       New  NaN  810140727244  NaN  ...       NaN
# 2032                  Y       New  NaN  195943428209  NaN  ...       NaN
# 2239                  Y       New  NaN  043662616127  NaN  ...       NaN
# 2265                  Y       New  NaN  191101221934  NaN  ...       NaN
# 2391                  Y       New  NaN  709248479608  NaN  ...       NaN
# 2542                  Y       New  NaN  848873085096  NaN  ...       NaN
#
#       Numeric2  Numeric3  Money1  Money2 Money3 Currency  Shipping Region  \
# 0         0.39       NaN     NaN     NaN    NaN      USD              NaN
# 54        0.42       NaN     NaN     NaN    NaN      USD              NaN
# 88        0.42       NaN     NaN     NaN    NaN      USD              NaN
# 183       0.40       NaN     NaN     NaN    NaN      USD              NaN
# 620       0.42       NaN     NaN     NaN    NaN      USD              NaN
# 692       0.27       NaN     NaN     NaN    NaN      USD              NaN
# 794       0.40       NaN     NaN     NaN    NaN      USD              NaN
# 846       0.45       NaN     NaN     NaN    NaN      USD              NaN
# 1387      0.31       NaN     NaN     NaN    NaN      USD              NaN
# 1467      0.30       NaN     NaN     NaN    NaN      USD              NaN
# 1488      0.42       NaN     NaN     NaN    NaN      USD              NaN
# 1506      0.39       NaN     NaN     NaN    NaN      USD              NaN
# 1524      0.50       NaN     NaN     NaN    NaN      USD              NaN
# 1604      0.39       NaN     NaN     NaN    NaN      USD              NaN
# 1652      0.27       NaN     NaN     NaN    NaN      USD              NaN
# 2032      0.42       NaN     NaN     NaN    NaN      USD              NaN
# 2239      0.38       NaN     NaN     NaN    NaN      USD              NaN
# 2265      0.30       NaN     NaN     NaN    NaN      USD              NaN
# 2391      0.44       NaN     NaN     NaN    NaN      USD              NaN
# 2542      0.40       NaN     NaN     NaN    NaN      USD              NaN
#
#      Labels  Promotion
# 0       NaN        NaN
# 54      NaN        NaN
# 88      NaN        NaN
# 183     NaN        NaN
# 620     NaN        NaN
# 692     NaN        NaN
# 794     NaN        NaN
# 846     NaN        NaN
# 1387    NaN        NaN
# 1467    NaN        NaN
# 1488    NaN        NaN
# 1506    NaN        NaN
# 1524    NaN        NaN
# 1604    NaN        NaN
# 1652    NaN        NaN
# 2032    NaN        NaN
# 2239    NaN        NaN
# 2265    NaN        NaN
# 2391    NaN        NaN
# 2542    NaN        NaN
#
# [20 rows x 70 columns]

# %% [markdown]
# ### Procesamiento para cargar a Shopify

# %%
to_shopify_df = new_df.loc[:, ['Unique Merchant SKU', 'Product Name', 'Product URL', 'Image URL', 'Current Price', 'Original Price', 'Product Description', 'Gender', 'Text1', 'Text2', 'Text3','Size']]

rename_dict = {
    'Unique Merchant SKU': 'ID',
    'Product Name': 'Title',
    'Product URL': 'Metafield: custom.product_url [url]',
    'Image URL': 'Image Src',
    'Current Price': 'Variant Price',
    'Original Price': 'Variant Compare At Price',
    'Product Description': 'Body HTML',
    'Gender': 'Metafield: custom.product_gender [single_line_text_field]',
    'Text1': 'Metafield: custom.text1 [single_line_text_field]',
    'Text2': 'Metafield: custom.text2 [single_line_text_field]',
    'Text3': 'Tags',
    'Size': 'Metafield: custom.sizes [single_line_text_field]'
}

to_shopify_df = to_shopify_df.rename(columns=rename_dict)



## remove emptyspaces in Tags column between values
to_shopify_df['Tags'] = to_shopify_df['Tags'].str.replace(' ', '')

# Create an additional column 'Variant Inventory Tracker' with all values value 'shopify'
to_shopify_df['Variant Inventory Tracker'] = 'shopify'
to_shopify_df['Variant Inventory Policy'] = 'continue'
to_shopify_df['Variant Fulfillment Service'] = 'manual'
to_shopify_df['Variant Inventory Qty'] = '1'
to_shopify_df['Status'] = 'Draft'

# edit the 'Tags' column to append ',NCAA' to each value
to_shopify_df['Tags'] = to_shopify_df['Tags'].apply(lambda x: x + ',FANATICS')

# %%
to_shopify_df.head(10)
# Out:
#              ID                                              Title  \
# 0       2866017  Women's Florida Panthers Sterling Silver Small...
# 54      4647126                  Silver Georgetown Hoyas Cufflinks
# 88      5180826             Gold San Francisco Dons Logo Cufflinks
# 183   201094121      BaubleBar Mickey & Minnie Heart Drop Earrings
# 620     4896760             Silver Nichols College Bison Cufflinks
# 692   200532585  Women's Texas Tech Red Raiders Enamel Hinge Ba...
# 794     4801665  Men's Silver Simmons University Sharks Tie Tac...
# 846   200070263  Brianna Cannon Tennessee Volunteers Large Word...
# 1387    2854885  Women's Oklahoma Sooners Sterling Silver XS Da...
# 1467    3627822  Women's Alabama Crimson Tide Sterling Silver L...
#
#                     Metafield: custom.product_url [url]  \
# 0     https://fanatics.93n6tx.net/c/5567077/669352/9...
# 54    https://fanatics.93n6tx.net/c/5567077/669352/9...
# 88    https://fanatics.93n6tx.net/c/5567077/669352/9...
# 183   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 620   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 692   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 794   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 846   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1387  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1467  https://fanatics.93n6tx.net/c/5567077/669352/9...
#
#                                               Image Src  Variant Price  \
# 0     https://feeds.frgimages.com/_pi2866000_ff_2866...          74.99
# 54    https://feeds.frgimages.com/_pi4647000_ff_4647...          79.99
# 88    https://feeds.frgimages.com/_pi5180000_ff_5180...          79.99
# 183   https://feeds.frgimages.com/_ss5_p-201094121+u...          57.99
# 620   https://feeds.frgimages.com/_pi4896000_ff_4896...          79.99
# 692   https://feeds.frgimages.com/_ss5_p-200532585+u...          46.00
# 794   https://feeds.frgimages.com/_pi4801000_ff_4801...          49.99
# 846   https://feeds.frgimages.com/_ss5_p-200070263+u...          74.99
# 1387  https://feeds.frgimages.com/_pi2854000_ff_2854...          59.99
# 1467  https://feeds.frgimages.com/_pi3627000_ff_3627...          54.99
#
#       Variant Compare At Price  \
# 0                        74.99
# 54                       79.99
# 88                       79.99
# 183                      57.99
# 620                      79.99
# 692                      46.00
# 794                      49.99
# 846                      74.99
# 1387                     59.99
# 1467                     54.99
#
#                                               Body HTML  \
# 0     Accessorize your outfit perfectly and show off...
# 54    These Georgetown Hoyas Cufflinks add a spirite...
# 88    These San Francisco Dons Logo Cufflinks add a ...
# 183   Display your love for Disney's most iconic cou...
# 620   These Cufflinks are perfect for adding that su...
# 692   This Texas Tech Red Raiders Enamel Hinge Bangl...
# 794   Adorn your business-wear with your Simmons Uni...
# 846   Add the perfect finishing touch to any Tenness...
# 1387  Show everyone you're a true fan as you flaunt ...
# 1467  Nothing accentuates your outfit like the perfe...
#
#      Metafield: custom.product_gender [single_line_text_field]  \
# 0                                                 Women
# 54                                                  Men
# 88                                                  Men
# 183                                               Women
# 620                                                 Men
# 692                                               Women
# 794                                                 Men
# 846                                               Women
# 1387                                              Women
# 1467                                              Women
#
#        Metafield: custom.text1 [single_line_text_field]  \
# 0     Sports & Outdoors~Fan Shop~Jewelry~Necklaces &...
# 54                          CuffLinks|HardLines|Jewelry
# 88                          CuffLinks|HardLines|Jewelry
# 183         Sports & Outdoors~Fan Shop~Jewelry~Earrings
# 620                         CuffLinks|HardLines|Jewelry
# 692        Sports & Outdoors~Fan Shop~Jewelry~Bracelets
# 794   Sports & Outdoors~Fan Shop~Jewelry~Necklaces &...
# 846         Sports & Outdoors~Fan Shop~Jewelry~Earrings
# 1387        Sports & Outdoors~Fan Shop~Jewelry~Earrings
# 1467          Sports & Outdoors~Fan Shop~Jewelry~Charms
#
#        Metafield: custom.text2 [single_line_text_field]  \
# 0                               Beads & Jewelry~Jewelry
# 54                         Beads & Jewelry~Jewelry~Ties
# 88                         Beads & Jewelry~Jewelry~Ties
# 183                             Beads & Jewelry~Jewelry
# 620                        Ties~Jewelry~Beads & Jewelry
# 692                             Jewelry~Beads & Jewelry
# 794   Patches & Pins~Jewelry~Beads & Jewelry~Pins & ...
# 846                             Beads & Jewelry~Jewelry
# 1387                            Beads & Jewelry~Jewelry
# 1467                            Jewelry~Beads & Jewelry
#
#                                   Tags  \
# 0             FloridaPanthers,FANATICS
# 54            GeorgetownHoyas,FANATICS
# 88           SanFranciscoDons,FANATICS
# 183            Mickey&Friends,FANATICS
# 620       NicholsCollegeBison,FANATICS
# 692       TexasTechRedRaiders,FANATICS
# 794   SimmonsUniversitySharks,FANATICS
# 846       TennesseeVolunteers,FANATICS
# 1387          OklahomaSooners,FANATICS
# 1467       AlabamaCrimsonTide,FANATICS
#
#      Metafield: custom.sizes [single_line_text_field]  \
# 0                                             No Size
# 54                                            No Size
# 88                                            No Size
# 183                                           No Size
# 620                                           No Size
# 692                                           No Size
# 794                                           No Size
# 846                                           No Size
# 1387                                          No Size
# 1467                                          No Size
#
#      Variant Inventory Tracker Variant Inventory Policy  \
# 0                      shopify                 continue
# 54                     shopify                 continue
# 88                     shopify                 continue
# 183                    shopify                 continue
# 620                    shopify                 continue
# 692                    shopify                 continue
# 794                    shopify                 continue
# 846                    shopify                 continue
# 1387                   shopify                 continue
# 1467                   shopify                 continue
#
#      Variant Fulfillment Service Variant Inventory Qty Status
# 0                         manual                     1  Draft
# 54                        manual                     1  Draft
# 88                        manual                     1  Draft
# 183                       manual                     1  Draft
# 620                       manual                     1  Draft
# 692                       manual                     1  Draft
# 794                       manual                     1  Draft
# 846                       manual                     1  Draft
# 1387                      manual                     1  Draft
# 1467                      manual                     1  Draft

# %% [markdown]
# # save as CSV
# to_shopify_df.to_csv("data/Products_Jewlery_for_Niko_Stones.csv", index=False)

# %%
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import gspread
from google.auth.transport.requests import Request
from google.oauth2.service_account import Credentials
from gspread_dataframe import set_with_dataframe

# Define the scope
scope = ["https://www.googleapis.com/auth/spreadsheets", "https://www.googleapis.com/auth/drive"]

# Add the path to your credentials file
creds = Credentials.from_service_account_file('credentials.json', scopes=scope)

# Authorize the client
client = gspread.authorize(creds)

# Open the Google Sheet by name
spreadsheet = client.open("Your Google Sheet Name")  # Replace with your sheet name

# Select the first sheet (or by index)
sheet = spreadsheet.sheet1 

# Example DataFrame
data = {'Name': ['John', 'Jane', 'Doe'],
        'Age': [23, 45, 32],
        'City': ['New York', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)

# Write the DataFrame to Google Sheets
set_with_dataframe(sheet, df)

print("DataFrame successfully written to Google Sheets!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import gspread
#       2 from google.auth.transport.requests import Request
#       3 from google.oauth2.service_account import Credentials
#
# ModuleNotFoundError: No module named 'gspread'
