# %%
import pandas as pd

# %%
df = pd.read_csv("data/Fanatics-Product-Catalog_IR.txt", sep="\t")
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_10320\1164394929.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Fanatics-Product-Catalog_IR.txt", sep="\t")

# %%
df.head()
# Out:
#    Unique Merchant SKU                                       Product Name  \
# 0              2866017  Women's Florida Panthers Sterling Silver Small...
# 1              5257010  Men's Under Armour Gray Virginia Tech Hokies S...
# 2            200180351  Women's Antigua  Navy Jacksonville Jumbo Shrim...
# 3            200465364   Keyscaper  Rey Mysterio Galaxy Impact Clear Case
# 4            201060326  Women's Cutter & Buck  Gray Los Angeles Dodger...
#
#                                          Product URL  \
# 0  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 3  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 4  https://fanatics.93n6tx.net/c/5567077/669352/9...
#
#                                            Image URL  Current Price  \
# 0  https://feeds.frgimages.com/_pi2866000_ff_2866...          74.99
# ...

# %%
df.shape
# Out:
# (960076, 70)

# %%
filtered_df = df[df['Product Name'].str.contains("Jewelry")]

# %%
filtered_df.head()
# Out:
#         Unique Merchant SKU  \
# 28020               5180713
# 225812            200825000
# 231141            200825001
# 236197            200825002
# 241408            200825003
#
#                                              Product Name  \
# 28020   WinCraft Utah Jazz Black Panther 2 Jewelry Car...
# 225812  Army Black Knights 4.5" x 5" x 2.25" Silver Pl...
# 231141  Penn State Nittany Lions 4.5" x 5" x 2.25" Sil...
# 236197  Louisville Cardinals 4.5" x 5" x 2.25" Silver ...
# 241408  Navy Midshipmen 4.5" x 5" x 2.25" Silver Plate...
#
#                                               Product URL  \
# 28020   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 225812  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 231141  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 236197  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 241408  https://fanatics.93n6tx.net/c/5567077/669352/9...
#
#                                                 Image URL  Current Price  \
# ...

# %%
# display df_filtered withut hiding any column
