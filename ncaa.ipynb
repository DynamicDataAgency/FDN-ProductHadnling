# %% [markdown]
# import csv
#
# # Define the filenames
# input_filename = 'Fanatics-Product-Catalog_IR.txt'
# output_filename = 'outputCollege2.csv'
#
# # Define the number of rows to extract
# num_rows = 1000000
#
# # Read the first 1000 rows from the input file and write the filtered rows to the CSV file
# try:
#     with open(input_filename, 'r', encoding='utf-8') as infile, open(output_filename, 'w', newline='', encoding='utf-8') as outfile:
#         reader = csv.reader(infile, delimiter='\t')
#         writer = csv.writer(outfile)
#
#         # Write header row
#         header = next(reader)
#         writer.writerow(header)
#
#         row_count = 0
#
#         for row in reader:
#             if row[18] == "College":  # Assuming the "Category" column is the second column (index 1)
#                 writer.writerow(row)
#                 row_count += 1
#                 if row_count >= num_rows:
#                     break
#
#     print(f"First {num_rows} rows with 'Category' as 'College' have been written to {output_filename}.")
# except FileNotFoundError:
#     print(f"File {input_filename} not found.")

# %%
import pandas as pd
test = pd.read_csv('outputCollege.csv')
test.head()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_1536\1979911520.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv('outputCollege.csv')
#    Unique Merchant SKU                                       Product Name  \
# 0              5257010  Men's Under Armour Gray Virginia Tech Hokies S...
# 1              5259694  Men's Champion Royal BYU Cougars Soccer Stack ...
# 2              3550368  Women's Concepts Sport  Charcoal Arizona State...
# 3            200683263  Men's GameDay Greats #1 White LSU Tigers Footb...
# 4              4313955  Men's Top of the World Orange Oklahoma State C...
#
#                                          Product URL  \
# 0  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2  https://fanatics.93n6tx.net/c/5567077/669352/9...
# 3  https://fanatics.93n6tx.net/c/5567077/669352/9...
# ...

# %%
import pandas as pd

df = pd.read_csv('outputCollege.csv')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_1536\1280949479.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('outputCollege.csv')

# %%
teams = [
     "Ohio State Buckeyes",
     "Michigan Wolverines",
     "Nittany Lions",
     "Crimson Tide",
     "Huskers",
     "Fighting Irish"
 ]

# exclude where Text3 contains any of the teams

df = df[~df['Text3'].str.contains('|'.join(teams))]


df['Text3'].value_counts()
# Out:
# Text3
# Florida Gators                       5611
# Clemson Tigers                       4954
# LSU Tigers                           4657
# Michigan State Spartans              4559
# Oklahoma Sooners                     4549
#                                      ...
# Anderson Trojans                        1
# Coastal Alabama Community College       1
# Scranton Univ Royals                    1
# Conference USA Gear                     1
# Alabama Huntsville Chargers             1
# Name: count, Length: 818, dtype: int64

# %%
#count different values in the column
df['Text3'].value_counts().head(55)
# Out:
# Text3
# Florida Gators                 5611
# Clemson Tigers                 4954
# LSU Tigers                     4657
# Michigan State Spartans        4559
# Oklahoma Sooners               4549
# Auburn Tigers                  4102
# Florida State Seminoles        4080
# Kentucky Wildcats              4069
# Texas A&M Aggies               3960
# Texas Longhorns                3926
# Tennessee Volunteers           3909
# Georgia Bulldogs               3854
# West Virginia Mountaineers     3823
# Wisconsin Badgers              3751
# North Carolina Tar Heels       3668
# Miami Hurricanes               3608
# Arkansas Razorbacks            3487
# Texas Tech Red Raiders         3447
# Iowa Hawkeyes                  3274
# Kansas Jayhawks                3140
# South Carolina Gamecocks       3128
# Oregon Ducks                   2939
# Ole Miss Rebels                2911
# Maryland Terrapins             2910
# Virginia Tech Hokies           2884
# Mississippi State Bulldogs     2825
# ...

# %%
# teams = [
#     "Ohio State Buckeyes",
#     "Michigan Wolverines",
#     "Nittany Lions",
#     "Crimson Tide",
#     "Huskers",
#     "Fighting Irish"
# ]

# %%
nf = df[df['Text1'].fillna('').str.contains("Sports & Outdoors~Fan Shop~Clothing & Accessories")]



# Count the occurrences of each value in the 'Text3' column of the 'nf' dataframe
# text3_counts = nf['Text3'].value_counts()

# Print the top 60 values
#  print(text3_counts.head(60))

nf = nf.loc[:, ['Unique Merchant SKU', 'Product Name', 'Product URL', 'Image URL', 'Current Price', 'Original Price', 'Product Description', 'Gender', 'Text1', 'Text2', 'Text3','Size']]

rename_dict = {
    'Unique Merchant SKU': 'ID',
    'Product Name': 'Title',
    'Product URL': 'Metafield: custom.product_url [url]',
    'Image URL': 'Image Src',
    'Current Price': 'Variant Price',
    'Original Price': 'Variant Compare At Price',
    'Product Description': 'Body HTML',
    'Gender': 'Metafield: custom.product_gender [single_line_text_field]',
    'Text1': 'Metafield: custom.text1 [single_line_text_field]',
    'Text2': 'Metafield: custom.text2 [single_line_text_field]',
    'Text3': 'Tags',
    'Size': 'Metafield: custom.sizes [single_line_text_field]'
}

nf = nf.rename(columns=rename_dict)



## remove emptyspaces in Tags column between values
nf['Tags'] = nf['Tags'].str.replace(' ', '')

# Create an additional column 'Variant Inventory Tracker' with all values value 'shopify'
nf['Variant Inventory Tracker'] = 'shopify'
nf['Variant Inventory Policy'] = 'continue'
nf['Variant Fulfillment Service'] = 'manual'
nf['Variant Inventory Qty'] = '1'




# # Split the DataFrame into multiple CSV files with less than 4,900 rows each
nf.to_csv(f'NCAA_Products_6teams.csv', index=False)

print("DataFrame saved to CSV files.")
# ## FILTERING NEW PRODUCTOS TO DISPLAY MOST SOLD JERSEYS
# Out:
# DataFrame saved to CSV files.

# %%
nf.head(10)
#nf.shape
# Out:
#            ID                                              Title  \
# 0     5257010  Men's Under Armour Gray Virginia Tech Hokies S...
# 1     5259694  Men's Champion Royal BYU Cougars Soccer Stack ...
# 2     3550368  Women's Concepts Sport  Charcoal Arizona State...
# 3   200683263  Men's GameDay Greats #1 White LSU Tigers Footb...
# 5     4983583  Men's Champion Black Florida State Seminoles H...
# 6   200129240  Women's Uscape Apparel Cream North Texas Mean ...
# 7     4517931  Youth Champion Black Cal State Stanislaus Warr...
# 8   200116433  Men's Colosseum Black Mississippi State Bulldo...
# 9   201281349  Women's Cutter & Buck  Black Texas A&M Aggies ...
# 11    4518165  Men's Champion Navy Carleton Knights Primary J...
#
#                   Metafield: custom.product_url [url]  \
# 0   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 1   https://fanatics.93n6tx.net/c/5567077/669352/9...
# 2   https://fanatics.93n6tx.net/c/5567077/669352/9...
# ...
